# %% [markdown]
# # **HANDS - ON: FUNDAMENTOS DE LLMS CON MODELOS LLAMA-**

# %% [markdown]
# Una vez vista la masterclass ***Fundamentos de LLMs y Arquitectura de Llama***, se proporciona el siguiente ***Colab*** para construir, en vivo, la primera llamada a Llama y medir su comportamiento.
#
# Usamos **Groq** para tener acceso a inferencia de Llama con GPU gratuita, sin necesidad de infraestructura propia.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/1bjMHw7fmMxo9dyQp140e9mqotKRkfKBg?usp=sharing).

# %% [markdown]
# ## **CONFIGURACIÓN DEL ENTORNO**

# %% [markdown]
# Antes de llamar a Llama necesitamos activar la GPU gratuita de Colab y conectar nuestra cuenta de **Groq**. La librería `groq` es el cliente oficial en Python para hacer llamadas a la API.

# %% [markdown]
# ### **COLAB SECRETS**

# %% [markdown]
# Para no exponer tu ***API key*** directamente en el código, Colab ofrece un panel de ***Secrets*** (ícono de llave en la barra lateral izquierda) donde puedes guardarla de forma segura, añadiendo un nombre asociado a la ***API key*** para guardarla dentro de una variable y usarla dentro del notebook.

# %%
# Instalar cliente de Groq y leer API key desde Colab Secrets
# !pip install groq -q  # Instalar la libreria de Groq

from groq import Groq  # Mandar a llamar
from google.colab import userdata

client = Groq(api_key=userdata.get('API_GROQ'))
print("Cliente de Groq inicializado correctamente.")
# Out:
# Cliente de Groq inicializado correctamente.

# %% [markdown]
# ## **DE PALABRAS A TOKENS**

# %% [markdown]
# Antes de que Llama genere una sola palabra, tu prompt se divide en **tokens**. Vamos a definir un prompt de ejemplo que después enviaremos a Llama.

# %%
# Definir un prompt de ejemplo (una pregunta real de tu propio contexto)
prompt = "¿Cuál es la diferencia entre la RAM y el almacenamiento en una computadora?"

# %% [markdown]
# ### **PRIMERA LLAMADA A LLAMA (ZERO-SHOT)**

# %% [markdown]
# Un LLM predice el siguiente token más probable, **no busca la respuesta en una base de datos**. Vamos a enviar el prompt a Llama en modo zero-shot (sin ejemplos previos) y ver la respuesta generada.

# %%
# Enviar el prompt a Llama en Groq y mostrar la respuesta generada
response = client.chat.completions.create(
    model = "openai/gpt-oss-20b",
    messages=[{"role":"user","content": prompt}]
)

print(response.choices[0].message.content)
# Out:
# **RAM (Random Access Memory) vs. Almacenamiento (HDD/SSD)**
#
# | Característica | RAM | Almacenamiento (HDD / SSD) |
# |-----------------|-----|---------------------------|
# | **Tipo de memoria** | Volátil: se pierde cuando la computadora se apaga. | No volátil: conserva datos incluso sin energía. |
# | **Función principal** | Guardar temporalmente los datos y programas que la CPU necesita usar *en ese momento*. | Almacenar permanentemente el sistema operativo, programas, archivos, fotos, videos, etc. |
# | **Velocidad** | Extremadamente rápida (nanosegundos). | Más lenta: <br>• HDD – milisegundos (rotación de platos). <br>• SSD – microsegundos (memoria flash). |
# | **Capacidad** | Generalmente menor (4 – 32 GB en un PC doméstico). | Mucho mayor (500 GB – 8 TB o más). |
# | **Costo por GB** | Más caro por gigabyte. | Más barato por gigabyte. |
# | **Acceso** | Acceso aleatorio; la CPU puede leer/escribir cualquier posición casi al instante. | Acceso aleatorio en SSD, pero con latencia más alta que RAM; HDD también tiene latencia por búsqueda y desplazamiento de cabezal. |
# | **Energía** | Consume energía mientras la computadora está encendida. | Consumo muy bajo; los HDD consumen más energía que SSD. |
#
# ### ¿Cómo interactúan?
#
# 1. **Arranque** – El BIOS/UEFI carga los primeros datos del sistema operativo desde el disco (HDD/SSD) a la RAM.
# 2. **Ejecutar programas** – Cuando abres un programa, el sistema operativo lo copia desde el disco a la RAM. La CPU trabaja con esos datos en RAM, porque es mucho más rápido que volver al disco.
# 3. **Cambios y guardados** – Cuando modificas un documento, los cambios se guardan en la RAM hasta que decides *guardar*. Al guardar, los datos se escriben de nuevo al disco para que persistan.
# 4. **Apagar** – Al apagar el equipo, los datos en RAM se borran; los archivos en el disco permanecen intactos.
#
# ### Analogía práctica
#
# - **RAM**: La mesa de trabajo. Cuando estás preparando una receta, pones los utensilios y los ingredientes en la mesa. Puedes moverlos, mezclarlos y cambiar la configuración de forma instantánea. Cuando cierras la cocina, la mesa se vacía.
# - **Almacenamiento**: La despensa. Los ingredientes se guardan allí para que estén disponibles en el futuro. Cuando quieres algo nuevo, lo sacas de la despensa y lo pones sobre la mesa de trabajo (RAM).
#
# ### Cuándo necesitas más RAM vs. más almacenamiento
#
# | Situación | Recomendación |
# |-----------|----------------|
# | **Trabajar con archivos muy grandes** (edición de video 4K, modelado 3D, bases de datos) | Más RAM, porque la CPU necesita acceder a los datos rápidamente. |
# | **Almacenar muchos archivos multimedia o juegos** | Más almacenamiento (espacio en disco). |
# | **Ejecución de múltiples programas simultáneamente** | Más RAM para evitar que el sistema tenga que intercambiar datos entre disco y memoria (swap). |
# | **Presupuesto limitado** | Prioriza el almacenamiento si necesitas espacio, pero trata de conseguir al menos 8 GB de RAM para la mayoría de las tareas modernas. |
#
# ### Resumen
#
# - **RAM**: Memoria de trabajo rápida y volátil que la CPU usa en tiempo real.
# - **Almacenamiento**: Memoria permanente que guarda todo lo que quieres conservar, con mayor capacidad y menor costo por GB, pero más lenta.
#
# Conocer esta diferencia te ayuda a planificar mejor las actualizaciones de tu computadora y a entender por qué la velocidad del sistema depende tanto de la RAM como del tipo de disco.

# %%
print(response.model_dump_json(indent=2))

# %% [markdown]
# ### **CUÁNTOS TOKENS CONSUMIÓ EL PROMPT**

# %% [markdown]
# La respuesta de la API trae un resumen (`usage`) con el número de tokens de entrada y de salida. Es la forma más directa de responder: ¿cuántos tokens consumió mi prompt?

# %%
# Mostrar cuántos tokens tuvo el prompt y cuántos tuvo la respuesta
print("Tokens de las promt:", response.usage.prompt_tokens)
print("Tokens de las respuestas:", response.usage.completion_tokens)
print("Tokens totales :", response.usage.total_tokens)
# Out:
# Tokens de las promt: 86
# Tokens de las respuestas: 733
# Tokens totales : 819

# %% [markdown]
# ### **MIDIENDO LA LATENCIA DE INFERENCIA**

# %% [markdown]
# Elegir el tamaño correcto de modelo es una decisión de ingeniería, no solo de potencia bruta. Vamos a medir cuánto tarda Llama en responder el mismo prompt.

# %%
# Medir el tiempo de respuesta de Llama para el mismo prompt
import time
inicio = time.time()
response_tiempo = client.chat.completions.create (
    model = "openai/gpt-oss-20b",
    messages=[{"role": "user","content": prompt}]
)
duracion =time.time() -inicio
print(f"Tiempo de respuesta: {duracion:.2f} segundos")
# Out:
# Tiempo de respuesta: 1.85 segundos

# %% [markdown]
# ### **COMPARANDO DOS TAMAÑOS DE MODELO**

# %% [markdown]
# Repite la misma llamada usando la versión más grande de Llama disponible en Groq y compara tiempo de respuesta y calidad contra el modelo ligero.

# %%
# Repetir la llamada con un modelo Llama más grande y comparar tiempo y calidad
# Medir el tiempo de respuesta de Llama para el mismo prompt
import time
inicio120b = time.time()
response_grande = client.chat.completions.create (
    model = "openai/gpt-oss-120b",
    messages=[{"role": "user","content": prompt}]
)
duracion_grande =time.time() -inicio120b
print(f"Modelo ligero: {duracion:.2f} s -{response.usage.total_tokens} tokens ")
print(f"Modelo grande: {duracion_grande:.2f} s -{response_grande.usage.total_tokens} tokens ")

# %% [markdown]
# ## **CHALLENGE: COMPARADOR DE MODELOS LLAMA**

# %% [markdown]
# Una vez visto el ***Hands-On: Fundamentos de LLMs***, se presenta el siguiente reto para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Se construirá un pequeño **comparador que envíe 3 preguntas** reales a Llama y registre, para cada una, el **tiempo de respuesta** y el **número de tokens** consumidos.

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# # 🏆 SOLUCIÓN AL CHALLENGE 1

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Carga la API key y genera 3 preguntas:**
#
#    * Lee la API key de llama ya configurada desde **Colab Secrets**.
#    * Construye una lista vacía llamada `preguntas` y agrégale 3 preguntas frecuentes de tu propio contexto (soporte técnico, tienda, escuela, etc.).

# %%
# Leer API key desde Colab Secrets
# !pip install groq -q  # Instalar la libreria de Groq

from groq import Groq  # Mandar a llamar
from google.colab import userdata

client = Groq(api_key=userdata.get('API_GROQ'))
print("Hola, estoy listo para tu consulta.")
# Out:
# Hola, estoy listo para tu consulta.

# %%
# Definir la lista de preguntas
question_1 = "¿Para qué se utiliza el rotacional y diveregencia en teoria electromagnética?"
question_2 = "¿Cuál es la utilididad de combinar un ESP32 y un STM32 en un placa de control?"
question_3 = "En qué casos se nesecita utilizar un transistor BJT, MOSFET, FET y ¿cuál es la polarizacion más común de cada uno? "

# %% [markdown]
# **2. Consulta la primera pregunta:** Envía la primera pregunta a Llama usando el modelo más ligero disponible en Groq. Guarda la respuesta, el tiempo de respuesta y el número de tokens en un diccionario llamado `resultado_1`.

# %%
# Consultar la primera pregunta y guardar el resultado en resultado_1

import time
inicio_1 = time.time()
response_1 = client.chat.completions.create(
    model = "openai/gpt-oss-20b",
    messages=[{"role":"user","content": question_1}]

)
tiempo_1 =time.time() -inicio_1


resultado_1 = {
    "Respuesta": response_1.choices[0].message.content,
    "tiempo" : tiempo_1,
    "Tokens" : response_1.usage.total_tokens
}

# %% [markdown]
# **3. Repite para la segunda y tercera pregunta:** Crea `resultado_2` y `resultado_3` de la misma forma.

# %%
# Consultar la segunda pregunta y guardar el resultado en resultado_2
import time
inicio_2 = time.time()
response_2 = client.chat.completions.create(
    model = "openai/gpt-oss-20b",
    messages=[{"role":"user","content": question_2}]

)
tiempo_2 =time.time() -inicio_2


resultado_2 = {
    "Respuesta": response_2.choices[0].message.content,
    "tiempo" : tiempo_2,
    "Tokens" : response_2.usage.total_tokens
}

# %%
# Consultar la tercera pregunta y guardar el resultado en resultado_3
import time
inicio_3 = time.time()
response_3 = client.chat.completions.create(
    model = "openai/gpt-oss-20b",
    messages=[{"role":"user","content": question_3}]

)
tiempo_3 =time.time() -inicio_3


resultado_3 = {
    "Respuesta": response_3.choices[0].message.content,
    "tiempo" : tiempo_3,
    "Tokens" : response_3.usage.total_tokens
}

# %% [markdown]
# **4. Junta los resultados:** Agrega `resultado_1`, `resultado_2` y `resultado_3` a una lista vacía llamada `resultados`.

# %%
# Definir la lista resultados y agregar los tres diccionarios
resultados = [resultado_1, resultado_2, resultado_3]

# %% [markdown]
# **5. Muestra la comparación:** Imprime `resultados` y concluye si el modelo ligero resolvió las 3 preguntas satisfactoriamente.

# %%
# Mostrar la tabla final de resultados
import pandas as pd

tabla_final = pd.DataFrame(resultados)
pd.set_option('display.max_colwidth', 100)
display(tabla_final)
# Out:
#                                                                                              Respuesta  \
# 0  ## El papel de la divergencia y el rotacional (curl) en la teoría electromagnética  \n\nEn elect...
# 1  ## ¿Para qué sirve combinar un ESP32 y un STM32 en la misma placa?\n\nCombinar estos dos microco...
# 2  ## 1.  Breve descripción de los tres tipos\n\n| Tipo | Característica principal | Conmutación | ...
#
#      tiempo  Tokens
# 0  2.368898    2137
# 1  2.202658    2058
# 2  2.435024    2153
